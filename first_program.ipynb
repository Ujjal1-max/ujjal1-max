# %% [markdown]
# <a href="https://colab.research.google.com/github/Ujjal1-max/ujjal1-max/blob/main/first_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Welcome Program**

# %%
print("Welcome to Skill Morph")
# Out:
# Welcome to Skill Morph
